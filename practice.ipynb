# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns
import numpy as np
from datetime import datetime
from IPython.display import Video

# %%
df = pd.read_csv('covid_19_data.csv',parse_dates=['ObservationDate','Last Update'])
df.head()
# Out:
#    SNo ObservationDate Province/State  Country/Region         Last Update  \
# 0    1      2020-01-22          Anhui  Mainland China 2020-01-22 17:00:00
# 1    2      2020-01-22        Beijing  Mainland China 2020-01-22 17:00:00
# 2    3      2020-01-22      Chongqing  Mainland China 2020-01-22 17:00:00
# 3    4      2020-01-22         Fujian  Mainland China 2020-01-22 17:00:00
# 4    5      2020-01-22          Gansu  Mainland China 2020-01-22 17:00:00
#
#    Confirmed  Deaths  Recovered
# 0        1.0     0.0        0.0
# 1       14.0     0.0        0.0
# 2        6.0     0.0        0.0
# 3        1.0     0.0        0.0
# 4        0.0     0.0        0.0

# %%
df.shape
# Out:
# (306429, 8)

# %%
df['Country/Region'].value_counts().head(25).plot(kind='bar')
plt.show()

# %%
dfCon=df.groupby('Country/Region')['Confirmed'].sum().reset_index().sort_values('Confirmed')
dfCon
# Out:
#       Country/Region     Confirmed
# 43             China  0.000000e+00
# 0         Azerbaijan  1.000000e+00
# 41   Channel Islands  1.000000e+00
# 59        East Timor  1.000000e+00
# 152    North Ireland  1.000000e+00
# ..               ...           ...
# 71            France  8.551890e+08
# 172           Russia  9.305488e+08
# 27            Brazil  2.653588e+09
# 96             India  3.226768e+09
# 214               US  6.049146e+09
#
# [229 rows x 2 columns]

# %%
sns.violinplot(x='Country/Region',y='Confirmed',data=dfCon.tail())
plt.show()

# %%
df['Country/Region'].unique()
# Out:
# array(['Mainland China', 'Hong Kong', 'Macau', 'Taiwan', 'US', 'Japan',
#        'Thailand', 'South Korea', 'China', 'Kiribati', 'Singapore',
#        'Philippines', 'Malaysia', 'Vietnam', 'Australia', 'Mexico',
#        'Brazil', 'Colombia', 'France', 'Nepal', 'Canada', 'Cambodia',
#        'Sri Lanka', 'Ivory Coast', 'Germany', 'Finland',
#        'United Arab Emirates', 'India', 'Italy', 'UK', 'Russia', 'Sweden',
#        'Spain', 'Belgium', 'Others', 'Egypt', 'Iran', 'Israel', 'Lebanon',
#        'Iraq', 'Oman', 'Afghanistan', 'Bahrain', 'Kuwait', 'Austria',
#        'Algeria', 'Croatia', 'Switzerland', 'Pakistan', 'Georgia',
#        'Greece', 'North Macedonia', 'Norway', 'Romania', 'Denmark',
#        'Estonia', 'Netherlands', 'San Marino', ' Azerbaijan', 'Belarus',
#        'Iceland', 'Lithuania', 'New Zealand', 'Nigeria', 'North Ireland',
#        'Ireland', 'Luxembourg', 'Monaco', 'Qatar', 'Ecuador',
#        'Azerbaijan', 'Czech Republic', 'Armenia', 'Dominican Republic',
#        'Indonesia', 'Portugal', 'Andorra', 'Latvia', 'Morocco',
#        'Saudi Arabia', 'Senegal', 'Argentina', 'Chile', 'Jordan',
#        'Ukraine', 'Saint Barthelemy', 'Hungary', 'Faroe Islands',
#        'Gibraltar', 'Liechtenstein', 'Poland', 'Tunisia', 'Palestine',
#        'Bosnia and Herzegovina', 'Slovenia', 'South Africa', 'Bhutan',
#        'Cameroon', 'Costa Rica', 'Peru', 'Serbia', 'Slovakia', 'Togo',
#        'Vatican City', 'French Guiana', 'Malta', 'Martinique',
#        'Republic of Ireland', 'Bulgaria', 'Maldives', 'Bangladesh',
#        'Moldova', 'Paraguay', 'Albania', 'Cyprus', 'St. Martin', 'Brunei',
#        'occupied Palestinian territory', "('St. Martin',)",
#        'Burkina Faso', 'Channel Islands', 'Holy See', 'Mongolia',
#        'Panama', 'Bolivia', 'Honduras', 'Congo (Kinshasa)', 'Jamaica',
#        'Reunion', 'Turkey', 'Cuba', 'Guyana', 'Kazakhstan',
#        'Cayman Islands', 'Guadeloupe', 'Ethiopia', 'Sudan', 'Guinea',
#        'Antigua and Barbuda', 'Aruba', 'Kenya', 'Uruguay', 'Ghana',
#        'Jersey', 'Namibia', 'Seychelles', 'Trinidad and Tobago',
#        'Venezuela', 'Curacao', 'Eswatini', 'Gabon', 'Guatemala',
#        'Guernsey', 'Mauritania', 'Rwanda', 'Saint Lucia',
#        'Saint Vincent and the Grenadines', 'Suriname', 'Kosovo',
#        'Central African Republic', 'Congo (Brazzaville)',
#        'Equatorial Guinea', 'Uzbekistan', 'Guam', 'Puerto Rico', 'Benin',
#        'Greenland', 'Liberia', 'Mayotte', 'Republic of the Congo',
#        'Somalia', 'Tanzania', 'The Bahamas', 'Barbados', 'Montenegro',
#        'The Gambia', 'Kyrgyzstan', 'Mauritius', 'Zambia', 'Djibouti',
#        'Gambia, The', 'Bahamas, The', 'Chad', 'El Salvador', 'Fiji',
#        'Nicaragua', 'Madagascar', 'Haiti', 'Angola', 'Cabo Verde',
#        'Niger', 'Papua New Guinea', 'Zimbabwe', 'Cape Verde',
#        'East Timor', 'Eritrea', 'Uganda', 'Bahamas', 'Dominica', 'Gambia',
#        'Grenada', 'Mozambique', 'Samoa', 'Syria', 'Timor-Leste', 'Belize',
#        'Laos', 'Libya', 'Diamond Princess', 'Guinea-Bissau', 'Mali',
#        'Saint Kitts and Nevis', 'West Bank and Gaza', 'Burma',
#        'MS Zaandam', 'Botswana', 'Burundi', 'Sierra Leone', 'Malawi',
#        'South Sudan', 'Sao Tome and Principe', 'Yemen', 'Comoros',
#        'Tajikistan', 'Lesotho', 'Solomon Islands', 'Marshall Islands',
#        'Vanuatu', 'Micronesia'], dtype=object)

# %%
data = df[df['Country/Region'] == 'India'] # Picking data of India

# %%
data.head()
# Out:
#      SNo ObservationDate Province/State Country/Region         Last Update  \
# 446  447      2020-01-30            NaN          India 2020-01-30 16:00:00
# 509  510      2020-01-31            NaN          India 2020-01-31 23:59:00
# 567  568      2020-02-01            NaN          India 2020-01-31 08:15:00
# 629  630      2020-02-02            NaN          India 2020-02-02 06:03:08
# 696  697      2020-02-03            NaN          India 2020-02-03 21:43:02
#
#      Confirmed  Deaths  Recovered
# 446        1.0     0.0        0.0
# 509        1.0     0.0        0.0
# 567        1.0     0.0        0.0
# 629        2.0     0.0        0.0
# 696        3.0     0.0        0.0

# %%
data['Confirmed'].head(50)
# Out:
# 446       1.0
# 509       1.0
# 567       1.0
# 629       2.0
# 696       3.0
# 766       3.0
# 838       3.0
# 911       3.0
# 986       3.0
# 1060      3.0
# 1134      3.0
# 1209      3.0
# 1283      3.0
# 1358      3.0
# 1433      3.0
# 1509      3.0
# 1586      3.0
# 1663      3.0
# 1740      3.0
# 1817      3.0
# 1894      3.0
# 1973      3.0
# 2055      3.0
# 2141      3.0
# 2227      3.0
# 2314      3.0
# 2409      3.0
# 2508      3.0
# 2615      3.0
# 2724      3.0
# 2847      3.0
# 2973      3.0
# 3096      5.0
# 3244      5.0
# 3372     28.0
# 3537     30.0
# 3712     31.0
# 3915     34.0
# 4143     39.0
# 4402     43.0
# 4669     56.0
# 4879     62.0
# 5096     73.0
# 5379     82.0
# 5555    102.0
# 5805    113.0
# 6075    119.0
# 6346    142.0
# 6626    156.0
# 6914    194.0
# Name: Confirmed, dtype: float64

# %%
#Plotting cumulative cases stored in the feature 'Confirmed

# %%
plt.figure(figsize = (12,7))
plt.plot(data['Confirmed'])
plt.show()

# %%
data.size
# Out:
# 105456

# %%
data.tail()
# Out:
#            SNo ObservationDate Province/State Country/Region  \
# 306351  306352      2021-05-29        Tripura          India
# 306366  306367      2021-05-29        Unknown          India
# 306377  306378      2021-05-29  Uttar Pradesh          India
# 306378  306379      2021-05-29    Uttarakhand          India
# 306406  306407      2021-05-29    West Bengal          India
#
#                Last Update  Confirmed   Deaths  Recovered
# 306351 2021-05-30 04:20:55    50739.0    507.0    43190.0
# 306366 2021-05-30 04:20:55        0.0      0.0        0.0
# 306377 2021-05-30 04:20:55  1688152.0  20208.0  1621743.0
# 306378 2021-05-30 04:20:55   327112.0   6360.0   289642.0
# 306406 2021-05-30 04:20:55  1354956.0  15268.0  1237290.0

# %%
# Taking data of West Bengal for analysis

# %%
data_west_bengal = data[data['Province/State'] == 'West Bengal']

# %%
data_west_bengal.head()
# Out:
#          SNo ObservationDate Province/State Country/Region  \
# 39779  39780      2020-06-10    West Bengal          India
# 40512  40513      2020-06-11    West Bengal          India
# 41245  41246      2020-06-12    West Bengal          India
# 41978  41979      2020-06-13    West Bengal          India
# 42711  42712      2020-06-14    West Bengal          India
#
#               Last Update  Confirmed  Deaths  Recovered
# 39779 2021-04-02 15:13:53     8985.0   415.0     3620.0
# 40512 2021-04-02 15:13:53     9768.0   442.0     3988.0
# 41245 2021-04-02 15:13:53     9768.0   442.0     3988.0
# 41978 2021-04-02 15:13:53    10244.0   451.0     4206.0
# 42711 2021-04-02 15:13:53    10698.0   463.0     4542.0

# %%
# Plotiing confirmed cases

# %%
plt.figure(figsize = (12,7))
plt.plot(data_west_bengal['Confirmed'])
plt.show()

# %%
# Plotiing deaths

# %%
plt.figure(figsize = (12,7))
plt.plot(data_west_bengal['Deaths'])
plt.show()

# %%
# The function plots the deaths and cases per day of a state and returns the lists 
# of cases/day and deaths/day
def plot_deaths_cases(data_original,place,ret  = False):
    data = data_original.reset_index()
    deaths = [0]
    j = 0
    for i in data['Deaths']:
        deaths.append(i-j)
        j = i
    deaths = deaths[2:]    
    confirmed = [0]
    j = 0
    for i in data['Confirmed']:
        confirmed.append(i-j)
        j = i 
    confirmed = confirmed[2:]    
    plt.subplot(2,1,1)    
#     plt.figure(figsize = (12,7))
    plt.plot(deaths[2:])
    plt.title('No of Deaths in '+place+' each day')
    plt.xlabel('Days')
    plt.ylabel('Deaths')
    plt.show()
    plt.subplot(2,1,2)
#     plt.figure(figsize = (12,7))
    plt.plot(confirmed[2:])
    plt.title('No of Cases in '+place+' each day')
    plt.xlabel('Days')
    plt.ylabel('Cases')
    plt.show()
    if ret:
        return deaths,confirmed

# %%
deaths = [0]
j = 0
for i in data_west_bengal['Deaths']:
     deaths.append(i-j)
     j = i

# %%
deaths = deaths[2:]

# %%
plot_deaths_cases(data_west_bengal,'West Bengal')

# %%
data['Province/State'].unique()
# Out:
# array([nan, 'Andaman and Nicobar Islands', 'Andhra Pradesh',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh',
#        'Chhattisgarh', 'Dadar Nagar Haveli', 'Delhi', 'Goa', 'Gujarat',
#        'Haryana', 'Himachal Pradesh', 'Jammu and Kashmir', 'Jharkhand',
#        'Karnataka', 'Kerala', 'Ladakh', 'Madhya Pradesh', 'Maharashtra',
#        'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha',
#        'Puducherry', 'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu',
#        'Telangana', 'Tripura', 'Unknown', 'Uttar Pradesh', 'Uttarakhand',
#        'West Bengal', 'Dadra and Nagar Haveli and Daman and Diu',
#        'Lakshadweep'], dtype=object)

# %%
# Picking data of Delhi for visualization

# %%
data_delhi = data[data['Province/State']=='Delhi']

# %%
plot_deaths_cases(data_delhi,'Delhi')

# %%
data['Deaths'].tail(20)
# Out:
# 306100      187.0
# 306101       31.0
# 306121     7959.0
# 306127    94030.0
# 306129      776.0
# 306142      551.0
# 306156       36.0
# 306168      350.0
# 306212     2686.0
# 306246     1497.0
# 306250    14305.0
# 306260     8251.0
# 306309      247.0
# 306330    23261.0
# 306334     3247.0
# 306351      507.0
# 306366        0.0
# 306377    20208.0
# 306378     6360.0
# 306406    15268.0
# Name: Deaths, dtype: float64

# %%
# Picking data of Uttar Pradesh for visualization

# %%
data_up = data[data['Province/State']=='Uttar Pradesh']

# %%
plot_deaths_cases(data_up,'Uttar Pradesh')

# %%
# Picking data of Maharashtra for visualization

# %%
data_maha = data[data['Province/State']=='Maharashtra']

# %%
deaths_maha,cases_maha = plot_deaths_cases(data_maha,'Maharashtra',ret = True)

# %% [markdown]
# **Picking Maharashtra's Data for analysis**

# %%
# Using Naive Prediction model

# %%
deaths_naive = [0]
cases_naive = [0]
for i in deaths_maha[1:]:
    deaths_naive.append(i)
for i in cases_maha[1:]:
    cases_naive.append(i)

# %%
plt.subplot(2,1,1)    
plt.plot(deaths_maha,label = 'Actual Deaths')
plt.plot(deaths_naive,label = 'Naive Forecast')
plt.legend(loc = 'upper left')
plt.title('Naive Deaths vs Actual Deaths')
plt.xlabel('Days')
plt.ylabel('Deaths')
plt.show()
plt.subplot(2,1,2)
plt.plot(cases_maha,label = 'Actual Cases')
plt.plot(cases_naive,label = 'Naive Forecast')
plt.legend(loc = 'upper left')
plt.title('Naive Cases vs Actual Cases')
plt.xlabel('Days')
plt.ylabel('Cases')
plt.show()

# %%
# Naive forecast works better than complex models sometimes as can be inferred from the graphs

# %%
! pip install bar_chart_race
# Out:
# Requirement already satisfied: bar_chart_race in c:\users\digipodium\appdata\local\programs\python\python39\lib\site-packages (0.1.0)
# Requirement already satisfied: pandas>=0.24 in c:\users\digipodium\appdata\local\programs\python\python39\lib\site-packages (from bar_chart_race) (1.3.2)
# Requirement already satisfied: matplotlib>=3.1 in c:\users\digipodium\appdata\local\programs\python\python39\lib\site-packages (from bar_chart_race) (3.4.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\digipodium\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.1->bar_chart_race) (2.4.7)
# Requirement already satisfied: numpy>=1.16 in c:\users\digipodium\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.1->bar_chart_race) (1.21.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\digipodium\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.1->bar_chart_race) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\digipodium\appdata\roaming\python\python39\site-packages (from matplotlib>=3.1->bar_chart_race) (2.8.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\digipodium\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.1->bar_chart_race) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\digipodium\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.1->bar_chart_race) (8.3.2)
# Requirement already satisfied: six in c:\users\digipodium\appdata\roaming\python\python39\site-packages (from cycler>=0.10->matplotlib>=3.1->bar_chart_race) (1.15.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\digipodium\appdata\local\programs\python\python39\lib\site-packages (from pandas>=0.24->bar_chart_race) (2021.1)
# WARNING: You are using pip version 21.2.3; however, version 21.3.1 is available.
# You should consider upgrading via the 'C:\Users\DIGIPODIUM\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.
